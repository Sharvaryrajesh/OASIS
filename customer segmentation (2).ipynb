# %%
#importing all the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data collection
df=pd.read_csv("C:\\Users\\sharv\\Downloads\\ifood_df.csv")

# %%
df.head(10)
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
# 5  62513.0        0         1       16       520         42               98
# 6  55635.0        0         1       34       235         65              164
# 7  33454.0        1         0       32        76         10               56
# 8  30351.0        1         0       19        14          0               24
# 9   5648.0        1         1       68        28          0                6
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# ...

# %%
df.tail()
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 2200              182               42               118           247  ...
# 2201               30                0                 0             8  ...
# 2202              217               32                12            24  ...
# 2203              214               80                30            61  ...
# 2204               61                2                 1            21  ...
#
#       marital_Together  marital_Widow  education_2n Cycle  education_Basic  \
# ...

# %%
df.shape
# Out:
# (2205, 39)

# %%
#data cleaning
df.isnull().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
df.nunique()
# Out:
# Income                  1963
# Kidhome                    3
# Teenhome                   3
# Recency                  100
# MntWines                 775
# MntFruits                158
# MntMeatProducts          551
# MntFishProducts          182
# MntSweetProducts         176
# MntGoldProds             212
# NumDealsPurchases         15
# NumWebPurchases           15
# NumCatalogPurchases       13
# NumStorePurchases         14
# NumWebVisitsMonth         16
# AcceptedCmp3               2
# AcceptedCmp4               2
# AcceptedCmp5               2
# AcceptedCmp1               2
# AcceptedCmp2               2
# Complain                   2
# Z_CostContact              1
# Z_Revenue                  1
# Response                   2
# Age                       56
# Customer_Days            662
# marital_Divorced           2
# marital_Married            2
# marital_Single             2
# marital_Together           2
# marital_Widow              2
# education_2n Cycle         2
# ...

# %%
df.drop(columns=["Z_CostContact","Z_Revenue"],inplace=True)

# %%
df.nunique()
# Out:
# Income                  1963
# Kidhome                    3
# Teenhome                   3
# Recency                  100
# MntWines                 775
# MntFruits                158
# MntMeatProducts          551
# MntFishProducts          182
# MntSweetProducts         176
# MntGoldProds             212
# NumDealsPurchases         15
# NumWebPurchases           15
# NumCatalogPurchases       13
# NumStorePurchases         14
# NumWebVisitsMonth         16
# AcceptedCmp3               2
# AcceptedCmp4               2
# AcceptedCmp5               2
# AcceptedCmp1               2
# AcceptedCmp2               2
# Complain                   2
# Response                   2
# Age                       56
# Customer_Days            662
# marital_Divorced           2
# marital_Married            2
# marital_Single             2
# marital_Together           2
# marital_Widow              2
# education_2n Cycle         2
# education_Basic            2
# education_Graduation       2
# ...

# %%
#descriptive analysis
df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
#data exploration
plt.figure(figsize=(4, 3))  
sns.boxplot(data=df, y="Income", palette="Greens")
plt.title("Income")
plt.show()

# %%
#plt.figure(figsize=(4,3))  
#sns.boxplot(data=df, y='MntTotal',palette="Paired")
#plt.title('Month Total')
#plt.show()

#hide outlier
plt.figure(figsize=(4,3))  
sns.boxplot(data=df, y="MntTotal",palette="Paired",fliersize=0)
plt.title("Month Total",fontsize=10)
plt.ylabel("Frequency",fontsize=10)
plt.show()

# %%
plt.figure(figsize=(4, 4))  
sns.histplot(x="Income", bins=30,data=df,color="green",alpha=0.5)
plt.title("Income",fontsize=12)
plt.xlabel("Income",fontsize=10)
plt.ylabel("Frequency",fontsize=10)
plt.show()
import warnings
warnings.filterwarnings("ignore")
df = df.replace([np.inf, -np.inf], np.nan)

# %%
plt.figure(figsize=(4, 4))  
sns.histplot(x="Age", data=df,bins=30,color="blue",alpha=0.3)
plt.title("Age")
plt.ylabel("Frequency")
plt.show()

# %%
#feature engineering
def marital_status(row):
    if row["marital_Married"] == 1:
        return "Married"
    elif row["marital_Divorced"] == 1:
        return "Divorced"
    elif row["marital_Together"] == 1:
        return "Together"
    elif row["marital_Single"] == 1:
        return "Single"
    elif row["marital_Widow"] == 1:
        return "Widow"
    
df["Marital"] = df.apply(marital_status, axis=1)
plt.figure(figsize=(6, 4))
sns.barplot(x="Marital", y="MntTotal", data=df, palette="CMRmap")
plt.title("Month Total by marital status")
plt.ylabel("MntTotal")
# Out:
# Text(0, 0.5, 'MntTotal')

# %%
#customer segmentation using k means algorithm
#importing machine learning library
from sklearn.cluster import KMeans

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
cols_for_clustering = ["Income", "MntTotal"]
data_scaled = df.copy()
data_scaled[cols_for_clustering] = scaler.fit_transform(df[cols_for_clustering])
data_scaled[cols_for_clustering].describe()
# Out:
#              Income      MntTotal
# count  2.205000e+03  2.205000e+03
# mean   2.255691e-17 -3.705778e-17
# std    1.000227e+00  1.000227e+00
# min   -2.409272e+00 -9.704038e-01
# 25%   -7.932106e-01 -8.800957e-01
# 50%   -1.618161e-02 -3.816642e-01
# 75%    8.044529e-01  6.968235e-01
# max    2.999363e+00  3.348757e+00

# %%
#elbow method
X = data_scaled[cols_for_clustering]
inertia_list = []
for K in range(2,10):
    inertia = KMeans(n_clusters=K, random_state=7).fit(X).inertia_
    inertia_list.append(inertia)

# %%
plt.figure(figsize=[4,3])
plt.plot(range(2,10), inertia_list, color=(54 / 255, 113 / 255, 130 / 255))
plt.title("Inertia vs. Number of Clusters")
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.show()

# %%
model = KMeans(n_clusters=4, random_state = 7)
model.fit(data_scaled[cols_for_clustering])
data_scaled["Cluster"] = model.predict(data_scaled[cols_for_clustering])

# %%
from sklearn import decomposition
pca = decomposition.PCA(n_components = 2)
pca_res = pca.fit_transform(data_scaled[cols_for_clustering])
data_scaled['pc1'] = pca_res[:,0]
data_scaled['pc2'] = pca_res[:,1]

# %%
#data visualisation
plt.figure(figsize=(4,3))
sns.scatterplot(x='pc1', y='pc2', data=data_scaled, hue='Cluster', palette='Accent')
plt.title('Clustered Data Visualization')
plt.xlabel('Principal Component 1 (pc1)')
plt.ylabel('Principal Component 2 (pc2)')
plt.legend(title='Clusters')

# %%
df['Cluster'] = data_scaled.Cluster
df.groupby('Cluster')[cols_for_clustering].mean()
# Out:
#                Income     MntTotal
# Cluster
# 0        27611.619942    64.612717
# 1        49373.049285   260.996820
# 2        79245.454286  1584.782857
# 3        67280.750936   893.900749

# %%
mnt_data = df.groupby('Cluster')["MntTotal"].mean().reset_index()
mnt_data.head()
# Out:
#    Cluster     MntTotal
# 0        0    64.612717
# 1        1   260.996820
# 2        2  1584.782857
# 3        3   893.900749

# %%
melted_data = pd.melt(mnt_data, id_vars="Cluster", var_name="Product", value_name="Consumption")
plt.figure(figsize=(8, 5))
sns.barplot(x="Cluster", y="Consumption", hue="Product", data=melted_data, ci=None, palette="Greens")
plt.title("Product Consumption by Cluster")
plt.xlabel("Cluster")
plt.ylabel("Product Consumption")
plt.xticks(rotation=0)  
plt.legend(title="Product", loc="upper right")

plt.show()

# %%
cluster_sizes = df.groupby('Cluster')[['MntTotal']].count().reset_index()
plt.figure(figsize=(8,6))
sns.barplot(x='Cluster', y='MntTotal', data=cluster_sizes, palette = 'Greens')
plt.title('Cluster sizes')
plt.xlabel('Cluster')
plt.ylabel('MntTotal')
# Out:
# Text(0, 0.5, 'MntTotal')

# %%
total_rows = len(df)
cluster_sizes['Share%'] = round(cluster_sizes['MntTotal'] / total_rows*100,0)
cluster_sizes.head()
# Out:
#    Cluster  MntTotal  Share%
# 0        0       692    31.0
# 1        1       629    29.0
# 2        2       350    16.0
# 3        3       534    24.0

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Cluster', y='Income', data=df, palette='Greens')
plt.title('Income by cluster')
plt.xlabel('Cluster')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Income', y='MntTotal', data=df, hue = 'Cluster', palette='Greens')
plt.title('Income by cluster')
plt.xlabel('Income')
plt.ylabel('MntTotal')
plt.legend(title='Clusters')
